# %%
#  Autoreload changes
# %load_ext autoreload
# %autoreload 2

from fuzzywuzzy import process
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from utils.book_quotes_utils import extract_book_quotes_from_json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_best_match(title, choices):
    best_match, score = process.extractOne(title, choices)
    return best_match,score

# %%
RAW_DIRECTORY = os.path.join(os.path.abspath(''),"0-RawData")

df = pd.read_csv(RAW_DIRECTORY+'/goodreads_library_export.csv')
read_df = df[df['Read Count']>=1].dropna(axis=1,how='all')
print(read_df.columns)
# Out:
# Index(['Book Id', 'Title', 'Author', 'Author l-f', 'Additional Authors',
#        'ISBN', 'ISBN13', 'My Rating', 'Average Rating', 'Publisher', 'Binding',
#        'Number of Pages', 'Year Published', 'Original Publication Year',
#        'Date Read', 'Date Added', 'Bookshelves', 'Bookshelves with positions',
#        'Exclusive Shelf', 'My Review', 'Spoiler', 'Read Count',
#        'Owned Copies'],
#       dtype='object')

# %% [markdown]
# ## Matching KeepNotes with Goodreads data

# %%
book_data = extract_book_quotes_from_json(directory=RAW_DIRECTORY+'/2-BookQuotes')

# %%
df_titles = read_df['Title'].tolist()
for ind, title_dict in enumerate(book_data):
    title = title_dict['title']
    best_match,score = get_best_match(title, df_titles)
    if score<=86:
        print(f"{ind} {score}- {title[:50]} \t -----  {best_match}")

# %% [markdown]
# #### Once corrections have been made

# %%
df_titles = read_df['Title'].tolist()
rows = []

for title_dict in book_data:
    title = title_dict['title']
    quote = title_dict['quotes']  # Assuming the quote key is 'quote'
    
    best_match, score = get_best_match(title, df_titles)
    
    # Skip those with low score
    if score<=86:
        continue
    rows.append({'Title': best_match, 'Quotes': quote})

# Create a new DataFrame
quotes_df = pd.DataFrame(rows)

read_df = pd.merge(read_df, quotes_df, on='Title', how='left')
# With the "exploded" format, each title and quote will have its own row, which often makes analysis and further processing easier.

# %%
import gensim
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim import corpora
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# nltk.download('punkt')
# nltk.download('stopwords')


# Step 1: Tokenization and Removing Stopwords
# Combine stopwords from all specified languages
stop_words = set()
languages = ['english', 'spanish', 'portuguese', 'french']  # Add or remove languages as needed

for lang in languages:
    stop_words.update(stopwords.words(lang))


def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [word for word in tokens if word.isalnum()]  # Removing punctuation
    tokens = [word for word in tokens if word not in stop_words]  # Removing stopwords
    return tokens

# Prepare all quotes
quotes = []
for row in read_df['Quotes']:
    if isinstance(row,list) and row:
        quotes+=row

processed_quotes = [preprocess_text(quote) for quote in quotes]

# Step 2: Building the Dictionary and Corpus
dictionary = corpora.Dictionary(processed_quotes)
corpus = [dictionary.doc2bow(text) for text in processed_quotes]

# Step 3: Applying LDA (Latent Dirichlet Allocation) for Topic Modeling
lda_model = gensim.models.LdaModel(corpus, num_topics=3, id2word=dictionary, passes=15)

topics = lda_model.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.008*"people" + 0.005*"world" + 0.004*"one" + 0.004*"us"')
# (1, '0.005*"one" + 0.003*"must" + 0.003*"world" + 0.003*"time"')
# (2, '0.009*"one" + 0.004*"brain" + 0.004*"world" + 0.003*"people"')

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el938621405705128434885040331250" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el938621405705128434885040331250_data = {"mdsDat": {"x": [-0.07618603137424854, -0.042138845488833704, 0.11832487686308224], "y": [0.08255118868299949, -0.10006689643897422, 0.01751570775597469], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [43.04524917656314, 32.72103047160634, 24.233720351830524]}, "tinfo": {"Term": ["us", "language", "one", "neural", "right", "consciousness", "something", "space", "use", "makes", "deterministic", "left", "else", "feelings", "play", "problem", "ask", "already", "first", "question", "step", "eyes", "meditation", "want", "reason", "selection", "idea", "writing", "moment", "state", "ask", "step", "question", "play", "according", "wrong", "answer", "players", "goes", "agent", "focused", "inputs", "sex", "designed", "task", "drive", "left", "concepts", "choice", "hypotheses", "material", "happening", "clearly", "finite", "stories", "realize", "available", "appropriate", "market", "interpreter", "role", "right", "already", "problem", "partner", "rules", "thought", "one", "speech", "nothing", "much", "want", "need", "would", "see", "say", "use", "understand", "place", "reality", "mind", "brain", "something", "rather", "instead", "take", "like", "way", "life", "time", "even", "people", "make", "work", "know", "new", "world", "person", "sensory", "may", "language", "selection", "creating", "useful", "cortical", "habits", "along", "via", "old", "resources", "stimuli", "religion", "government", "goal", "escape", "skill", "key", "survival", "represented", "signaling", "physically", "effort", "naturally", "various", "altered", "advice", "continuously", "saw", "primates", "robots", "education", "content", "hierarchy", "symbolic", "sensations", "else", "consciousness", "space", "entropy", "yet", "idea", "found", "state", "always", "cortex", "people", "knowledge", "experience", "moment", "world", "better", "visual", "information", "subjective", "actions", "power", "never", "physical", "anything", "often", "also", "change", "well", "way", "might", "using", "time", "something", "one", "less", "action", "life", "brain", "many", "us", "new", "make", "deterministic", "face", "eyes", "po", "meditation", "spiritual", "laughter", "pineal", "worlds", "color", "trick", "national", "quickly", "coherent", "sistema", "randomness", "neural", "race", "judge", "tells", "invisible", "contact", "contrast", "sino", "stage", "risks", "thumb", "carefully", "chaotic", "4chan", "determinism", "access", "possibilities", "price", "writing", "reaction", "define", "us", "makes", "feels", "language", "feelings", "reason", "manner", "function", "associated", "looking", "exist", "however", "human", "like", "may", "thus", "emotions", "world", "every", "means", "system", "brain", "without", "things", "make", "sense", "others", "people", "self", "experience", "person", "use", "less", "life", "way"], "Freq": [117.0, 82.0, 260.0, 29.0, 53.0, 77.0, 86.0, 36.0, 57.0, 44.0, 16.0, 31.0, 30.0, 29.0, 27.0, 45.0, 25.0, 35.0, 46.0, 25.0, 24.0, 13.0, 13.0, 57.0, 23.0, 16.0, 61.0, 16.0, 36.0, 64.0, 24.746976036070894, 23.848393245828966, 24.725514022172018, 26.51396416249987, 19.60132239557185, 20.961556208967, 18.38615549914383, 15.751445389119798, 15.976562643082488, 14.977695165356677, 14.962813384224608, 14.958816741620298, 16.226672925283783, 14.81600682832453, 18.88034660865739, 12.891365809823098, 30.424193921375263, 14.829536994077472, 13.122126650807408, 11.210200948595903, 11.199476408705696, 11.246311929494556, 11.72618065849947, 10.996319132202613, 13.165784689827793, 11.110803326069773, 10.669869527160735, 11.23853313508374, 10.121347575210422, 9.761759680829407, 16.03857742972801, 50.342982098874934, 32.737881366894825, 40.71658766832404, 17.787987011325896, 24.899281748003116, 37.02295265718904, 190.98279606521166, 14.816451977568216, 35.912127450068695, 49.99776185441718, 43.964349125141275, 52.470006502458226, 70.55646985412544, 45.73396503330416, 40.325395255484665, 41.16955774230382, 25.22224453027667, 31.6342324398 ...

# %%
# Define a function to export the top terms for a given topic
def export_top_terms(model, topic_id, num_terms=30, filepath='topic_terms.txt'):
    """
    Exports the top terms for a given topic to a text file.
    
    :param model: Trained LDA model
    :param topic_id: ID of the topic for which terms should be exported
    :param num_terms: Number of top terms to export
    :param filepath: Path to the output text file
    """
    # Get the terms for the given topic
    terms = model.show_topic(topic_id, num_terms)
    
    # Open the file for writing
    with open(filepath, 'w') as file:
        # Write each term and its weight to the file
        for term, weight in terms:
            file.write(f'{term}: {weight}\n')

# Usage
export_top_terms(lda_model, topic_id=0)  # topic_id is zero-indexed
